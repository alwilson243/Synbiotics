# %%
import pandas as pd

# %%
class omim_txt():
    """omim description object."""

    description_fields = ["DESCRIPTION", "CLINICAL FEATURES", "INHERITANCE", "PATHOGENESIS", "GENE FUNCTION", "MAPPING"]

    def __init__(self):
        self.description = ""
        self.clinical_features = ""
        self.gene_function = ""
        self.descriptions = {}
    
    def fill(text):
        description = text.split("\t")
        word_ls = list()
        category = ""
        
        for i, word in enumerate(description):
            word_plus = word + " " + description[i]
            
            if word in description_fields or word_plus in description_fields and i != 0:
                if category != "":
                    self.descriptions[category] = " ".join(word_ls)
                    word_ls = 
                
                if word in description_fields:
                    category = word 
                elif word_plus in description_fields
                    category = word_plus
                    
                    
                word_ls += [word]

# %%
df = pd.DataFrame.from_csv("vcf_omim_df.csv")

# %%
description_fields = ["DESCRIPTION", "CLINICAL FEATURES", "INHERITANCE", "PATHOGENESIS", "GENE FUNCTION", "MAPPING"]
description = df.iloc[0,3].strip()
description = description.split()
description
# Out:
# ['CLONING',
#  'Based',
#  'on',
#  'homology',
#  'with',
#  'SPHK1',
#  '(603730),',
#  'Liu',
#  'et',
#  'al.',
#  '(2000)',
#  'identified',
#  'an',
#  'EST',
#  'containing',
#  'SPHK2',
#  'and',
#  'cloned',
#  'the',
#  'gene',
#  'by',
#  'nested',
#  'PCR',
#  'and',
#  '5-prime',
#  'RACE',
#  'of',
#  'human',
#  'embryonic',
#  'kidney',
#  'cell',
#  'RNA.',
#  'The',
#  'deduced',
#  '618-amino',
#  'acid',
#  'protein',
#  'has',
#  'a',
#  'calculated',
#  'molecular',
#  'mass',
#  'of',
#  '65.2',
#  'kD.',
#  'SPHK2',
#  'contains',
#  'the',
#  '5',
#  'highly',
#  'conserved',
#  'regions',
#  'identified',
#  'in',
#  'SPHK1,',
#  'although',
#  'the',
#  'GGKGK',
#  'positively',
#  'charged',
#  'motif',
#  'of',
#  'SPHK1',
#  'is',
#  'modified',
#  'to',
#  'GGRGL',
#  'in',
#  'SPHK2.',
#  'In',
#  'addition,',
#  'SPHK2',
#  'has',
#  'a',
#  'region',
#  'homologous',
#  'to',
#  'the',
#  'diacylglycerol',
#  'kinase',
#  '(see',
#  'DGKA;',
# ...

# %%
df
# Out:
#          rs_id  mim_id                                                 TI  \
# 0      1801131  607093   *607093 5,10-@METHYLENETETRAHYDROFOLATE REDUC...
# 1      1801133  607093   *607093 5,10-@METHYLENETETRAHYDROFOLATE REDUC...
# 2        13551  230000   #230000 FUCOSIDOSIS ;;ALPHA-L-FUCOSIDASE DEFI...
# 3     17292650  159530   *159530 MYELOPROLIFERATIVE LEUKEMIA VIRUS ONC...
# 4     28928908  159530   *159530 MYELOPROLIFERATIVE LEUKEMIA VIRUS ONC...
# 5     28928907  159530   *159530 MYELOPROLIFERATIVE LEUKEMIA VIRUS ONC...
# 6       324420  602935           *602935 FATTY ACID AMIDE HYDROLASE; FAAH
# 7      4630153  604566      *604566 ALG6, S. CEREVISIAE, HOMOLOG OF; ALG6
# 8      1137100  601007                *601007 LEPTIN RECEPTOR; LEPR ;;OBR
# 9      1137101  601007                *601007 LEPTIN RECEPTOR; LEPR ;;OBR
# 10     8179183  601007                *601007 LEPTIN RECEPTOR; LEPR ;;OBR
# 11     1801265  274270   #274270 DIHYDROPYRIMIDINE DEHYDROGENASE DEFIC...
# ...
